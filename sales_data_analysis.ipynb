# %%
import pandas as pd
import matplotlib.pyplot as plt
from itertools import combinations
from collections import Counter

# %% [markdown]
# #### Merge data from each month into one CSV

# %%
files = ['Sales_April_2019.csv',
              'Sales_August_2019.csv',
              'Sales_December_2019.csv',
              'Sales_February_2019.csv',
              'Sales_January_2019.csv',
              'Sales_July_2019.csv',
              'Sales_June_2019.csv',
              'Sales_March_2019.csv',
              'Sales_May_2019.csv',
              'Sales_November_2019.csv',
              'Sales_October_2019.csv',
              'Sales_September_2019.csv']

# %%
all_months_data = pd.DataFrame()

for file in files:
    current_data = pd.read_csv(file)
    all_months_data = pd.concat([all_months_data, current_data])

all_months_data.to_csv("merged_data.csv", index=False)

# %%
sales_df = pd.read_csv('merged_data.csv')

sales_df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %% [markdown]
# ### Clean up the data!

# %%
temp_df = sales_df[sales_df['Order Date'] == 'Order Date']

# %%
sales_df = sales_df[sales_df['Order Date'] != 'Order Date']

# %%
nan_df = sales_df[sales_df['Order Date'].isna()]

# %%
sales_df = sales_df.dropna(axis=0,how='all')

# %%
pd.to_datetime(sales_df['Order Date'][0]).month
# Out:
# 4

# %%
sales_df['Order Date'] = pd.to_datetime(sales_df['Order Date'])

# %% [markdown]
# ### Augment data with additional columns

# %%
sales_df['Month'] = sales_df['Order Date'].dt.month.astype('int')

# %%
sales_df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#            Order Date                      Purchase Address  Month
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4

# %%
# type(sales_df['Quantity Ordered'])
# type(sales_df['Price Each'])

sales_df['Quantity Ordered'] = sales_df['Quantity Ordered'].astype('int')
sales_df['Price Each'] = sales_df['Price Each'].astype('float')

# %%
sales_df['Sales'] = sales_df['Quantity Ordered'] * sales_df['Price Each']

# %%
sales_df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month   Sales
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99

# %%
sales_df[['Street_Address', 'City', 'Zip_Code']] = sales_df['Purchase Address'].str.split(",",2,expand=True)
# Out:
# <ipython-input-16-dacf1c99a70b>:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   sales_df[['Street_Address', 'City', 'Zip_Code']] = sales_df['Purchase Address'].str.split(",",2,expand=True)

# %%
sales_df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#     Street_Address          City   Zip_Code
# 0       917 1st St        Dallas   TX 75001
# ...

# %%
sales_df['State'] = sales_df['Zip_Code'].str.split(' ',2,expand=True)[1]
# Out:
# <ipython-input-18-2184d426d6ec>:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   sales_df['State'] = sales_df['Zip_Code'].str.split(' ',2,expand=True)[1]

# %%
sales_df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#     Street_Address          City   Zip_Code State
# ...

# %%
sales_df['Hour'] = sales_df['Order Date'].dt.hour.astype('int')

# %%
sales_df['Minute'] = sales_df['Order Date'].dt.minute.astype('int')

# %%
sales_df['Count'] = 1

# %%
sales_df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#     Street_Address          City   Zip_Code State  Hour  Minute  Count
# ...

# %% [markdown]
# ### Question 1: What was the best month for sales? How much was earned that month?

# %%
results = sales_df.groupby('Month').sum()

results
# Out:
# <ipython-input-24-cc6e1b3ace69>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   results = sales_df.groupby('Month').sum()
#        Quantity Ordered  Price Each       Sales    Hour  Minute  Count
# Month
# 1                 10903  1811768.38  1822256.73  139485  282440   9709
# 2                 13449  2188884.72  2202022.42  172669  354885  11975
# 3                 17005  2791207.83  2807100.38  218969  447559  15153
# 4                 20558  3367671.02  3390670.24  262259  544186  18279
# 5                 18667  3135125.13  3152606.75  238780  487899  16566
# 6                 15253  2562025.61  2577802.26  195528  402436  13554
# 7                 16072  2632539.56  2647775.76  206169  417349  14293
# 8                 13448  2230345.42  2244467.88  172289  353857  11961
# ...

# %%
months = range(1,13)
plt.bar(months,results['Sales'])
plt.xticks(months)
plt.ylabel('Sales in USD ($)')
plt.xlabel('Month')
plt.show()

# %% [markdown]
# ### Question 2: What city sold the most product?

# %%
results2 = sales_df.groupby(['City','State']).sum()

results2
# Out:
# <ipython-input-26-78a47ea848e8>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   results2 = sales_df.groupby(['City','State']).sum()
#                       Quantity Ordered  Price Each   Month       Sales  \
# City           State
#  Atlanta       GA                16602  2779908.20  104794  2795498.58
#  Austin        TX                11153  1809873.61   69829  1819581.75
#  Boston        MA                22528  3637409.77  141112  3661642.01
#  Dallas        TX                16730  2752627.82  104620  2767975.40
#  Los Angeles   CA                33289  5421435.23  208325  5452570.80
#  New York City NY                27932  4635370.83  175741  4664317.43
#  Portland      ME                 2750   447189.25   17144   449758.27
# ...

# %% [markdown]
# ### Question 3: What time should we display advertisements to maximize likelihood of customer's buying product?

# %%
sales_df.groupby(['Hour']).count()
# Out:
#       Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# Hour
# 0         3910     3910              3910        3910        3910
# 1         2350     2350              2350        2350        2350
# 2         1243     1243              1243        1243        1243
# 3          831      831               831         831         831
# 4          854      854               854         854         854
# 5         1321     1321              1321        1321        1321
# 6         2482     2482              2482        2482        2482
# 7         4011     4011              4011        4011        4011
# 8         6256     6256              6256        6256        6256
# 9         8748     8748              8748        8748        8748
# 10       10944    10944             10944       10944       10944
# 11       12411    12411             12411       12411       12411
# 12       12587    12587             12587       12587       12587
# ...

# %%
hours = [hour for hour, df in sales_df.groupby('Hour')]

plt.plot(hours, sales_df.groupby(['Hour']).count())
plt.xticks(hours)
plt.xlabel('Hour')
plt.ylabel('Number of Orders')
plt.grid()
plt.show()

# %% [markdown]
# ### Question 4: What products are most often sold together?

# %%
dup_df = sales_df[sales_df['Order ID'].duplicated(keep=False)]
dup_df.head(20)
# Out:
#     Order ID                     Product  Quantity Ordered  Price Each  \
# 3     176560                Google Phone                 1      600.00
# 4     176560            Wired Headphones                 1       11.99
# 18    176574                Google Phone                 1      600.00
# 19    176574        USB-C Charging Cable                 1       11.95
# 30    176585  Bose SoundSport Headphones                 1       99.99
# 31    176585  Bose SoundSport Headphones                 1       99.99
# 32    176586      AAA Batteries (4-pack)                 2        2.99
# 33    176586                Google Phone                 1      600.00
# 119   176672    Lightning Charging Cable                 1       14.95
# 120   176672        USB-C Charging Cable                 1       11.95
# 129   176681    Apple Airpods Headphones                 1      150.00
# 130   176681             ThinkPad Laptop                 1      999.99
# ...

# %%
dup_df['Grouped'] = dup_df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))

dup_df.head(20)
# Out:
# <ipython-input-30-3a384b3c3b3a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dup_df['Grouped'] = dup_df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
#     Order ID                     Product  Quantity Ordered  Price Each  \
# 3     176560                Google Phone                 1      600.00
# 4     176560            Wired Headphones                 1       11.99
# 18    176574                Google Phone                 1      600.00
# 19    176574        USB-C Charging Cable                 1       11.95
# 30    176585  Bose SoundSport Headphones                 1       99.99
# 31    176585  Bose SoundSport Headphones                 1       99.99
# ...

# %%
dup_df = dup_df[['Order ID', 'Grouped']].drop_duplicates()

dup_df.head(10)
# Out:
#     Order ID                                            Grouped
# 3     176560                      Google Phone,Wired Headphones
# 18    176574                  Google Phone,USB-C Charging Cable
# 30    176585  Bose SoundSport Headphones,Bose SoundSport Hea...
# 32    176586                AAA Batteries (4-pack),Google Phone
# 119   176672      Lightning Charging Cable,USB-C Charging Cable
# 129   176681           Apple Airpods Headphones,ThinkPad Laptop
# 138   176689  Bose SoundSport Headphones,AAA Batteries (4-pack)
# 189   176739                34in Ultrawide Monitor,Google Phone
# 225   176774      Lightning Charging Cable,USB-C Charging Cable
# 233   176781                    iPhone,Lightning Charging Cable

# %%
count = Counter()

for row in dup_df['Grouped']:
  row_list = row.split(',')
  count.update(Counter(combinations(row_list,2)))


for key, value in count.most_common(10):
  print(key, value)
# Out:
# ('iPhone', 'Lightning Charging Cable') 1005
# ('Google Phone', 'USB-C Charging Cable') 987
# ('iPhone', 'Wired Headphones') 447
# ('Google Phone', 'Wired Headphones') 414
# ('Vareebadd Phone', 'USB-C Charging Cable') 361
# ('iPhone', 'Apple Airpods Headphones') 360
# ('Google Phone', 'Bose SoundSport Headphones') 220
# ('USB-C Charging Cable', 'Wired Headphones') 160
# ('Vareebadd Phone', 'Wired Headphones') 143
# ('Lightning Charging Cable', 'Wired Headphones') 92

# %% [markdown]
# ### Question 5: What product sold the most? Why do you think it sold the most?

# %%
sales_df.groupby('Product').sum()['Quantity Ordered']
# Out:
# <ipython-input-33-41408dd2f08e>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales_df.groupby('Product').sum()['Quantity Ordered']
# Product
# 20in Monitor                   4129
# 27in 4K Gaming Monitor         6244
# 27in FHD Monitor               7550
# 34in Ultrawide Monitor         6199
# AA Batteries (4-pack)         27635
# AAA Batteries (4-pack)        31017
# Apple Airpods Headphones      15661
# Bose SoundSport Headphones    13457
# Flatscreen TV                  4819
# Google Phone                   5532
# LG Dryer                        646
# LG Washing Machine              666
# Lightning Charging Cable      23217
# Macbook Pro Laptop             4728
# ThinkPad Laptop                4130
# USB-C Charging Cable          23975
# Vareebadd Phone                2068
# ...

# %%
products = [prod for prod, df in sales_df.groupby('Product')]
plt.bar(products, sales_df.groupby('Product').sum()['Quantity Ordered'])
plt.xticks(rotation='vertical')
plt.xlabel('Product')
plt.ylabel('Quantity Ordered')
plt.show()
# Out:
# <ipython-input-34-21448c4f36a4>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   plt.bar(products, sales_df.groupby('Product').sum()['Quantity Ordered'])

# %%
sales_df.groupby('Product').mean()['Price Each']
# Out:
# <ipython-input-35-9460db875564>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales_df.groupby('Product').mean()['Price Each']
# Product
# 20in Monitor                   109.99
# 27in 4K Gaming Monitor         389.99
# 27in FHD Monitor               149.99
# 34in Ultrawide Monitor         379.99
# AA Batteries (4-pack)            3.84
# AAA Batteries (4-pack)           2.99
# Apple Airpods Headphones       150.00
# Bose SoundSport Headphones      99.99
# Flatscreen TV                  300.00
# Google Phone                   600.00
# LG Dryer                       600.00
# LG Washing Machine             600.00
# Lightning Charging Cable        14.95
# Macbook Pro Laptop            1700.00
# ThinkPad Laptop                999.99
# USB-C Charging Cable            11.95
# ...

# %%
fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.bar(products, sales_df.groupby('Product').sum()['Quantity Ordered'])
ax2.plot(products, sales_df.groupby('Product').mean()['Price Each'],'-g')

ax1.set_xlabel('Product Name')
ax1.set_ylabel('Quantity Ordered')
ax2.set_ylabel('Price of Each (USD)')

ax1.set_xticklabels(products,rotation='vertical')

plt.show()
# Out:
# <ipython-input-36-468f073032c2>:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ax1.bar(products, sales_df.groupby('Product').sum()['Quantity Ordered'])
# <ipython-input-36-468f073032c2>:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ax2.plot(products, sales_df.groupby('Product').mean()['Price Each'],'-g')
# <ipython-input-36-468f073032c2>:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(products,rotation='vertical')
